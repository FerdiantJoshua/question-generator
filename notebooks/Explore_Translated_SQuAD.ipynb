# %%
import pandas as pd

# %%
SQUAD_TRANSLATED_DATASET_PATH = f'../data/interim/train-v2.0-translated.json'
SQUAD_FINAL_DATASET_PATH = f'../data/processed/train-v2.0-translated_fixed_enhanced.json'

df_squad = pd.read_json(SQUAD_FINAL_DATASET_PATH)
df_squad = df_squad
print(df_squad.shape)
# Out:
# (442, 2)

# %%
df_squad.head(2)
# Out:
#              title                                         paragraphs
# 0          Beyonce  [{'qas': [{'question': 'Kapan Beyonce mulai me...
# 1  Frédéric Chopin  [{'qas': [{'question': 'Bagaimana kewarganegar...

# %%
df_squad.iloc[1]['paragraphs']
# Out:
# [{'qas': [{'question': 'Bagaimana kewarganegaraan Frédéric?',
#     'id': '56cbd2356d243a140015ed66',
#     'answers': [{'text': 'Polandia dan Prancis', 'answer_start': 182}],
#     'is_impossible': False,
#     'indonesian_answers': [{'text': 'Polandia dan komposer Prancis',
#       'answer_start': 201,
#       'answer_end': 230}],
#     'postags': [[['Bagaimana', 'ADV'],
#       ['kewarganegaraan', 'NNO'],
#       ['Frederic', 'NNP'],
#       ['?', 'PUN']]],
#     'entities': [{'begin_offset': 26,
#       'length': 8,
#       'name': 'Frederic',
#       'type': 'ORG'}]},
#    {'question': 'Di era apa Frédéric aktif?',
#     'id': '56cbd2356d243a140015ed67',
#     'answers': [{'text': 'Era romantis', 'answer_start': 276}],
#     'is_impossible': False,
#     'indonesian_answers': [{'text': 'era Romantis',
#       'answer_start': 313,
#       'answer_end': 325}],
#     'postags': [[['Di', 'PPO'],
#       ['era', 'NNO'],
#       ['apa', 'PRI'],
#       ['Frederic', 'NNP'],
# ...
